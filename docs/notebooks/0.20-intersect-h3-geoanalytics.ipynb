# %% [markdown]
# # Spatial Join with H3 and GeoAnalytics
#
# Using H3 indices to lower the computational load when performing a spatial join between points and polygons.

# %% [markdown]
# ## Setup and Initialization

# %% [markdown]
# ### Imports

# %%
import json
from pathlib import Path

import geoanalytics_fabric.sql.functions as fns_ga
from geoanalytics_fabric.sql import Polygon
from h3.api import basic_int as h3_int
from pyspark.sql import SparkSession
import pyspark.sql.functions as fns
from pyspark.sql.types import ArrayType, IntegerType, StringType, LongType
# Out:
# StatementMeta(, ea3b6b13-c2f8-4484-aeb1-7bda22e32c2d, 5, Finished, Available, Finished)

# %% [markdown]
# ### Parameters for Integration into Pipeline

# %%
# year=2025
# month=7
# day=8

# delivery date parts
year=0
month=0
day=0

# h3 resolution
h3_res = 9
h3_col = f"h3_{h3_res:02d}"

# US States in Living Atlas Feature Layer URL with WA query applied
poly_url = "https://services.arcgis.com/P3ePLMYs2RVChkJx/ArcGIS/rest/services/USA_Boundaries_2023/FeatureServer/1"
# Out:
# StatementMeta(, ea3b6b13-c2f8-4484-aeb1-7bda22e32c2d, 6, Finished, Available, Finished)

# %% [markdown]
# ### Introspectively Get Most Recent Year, Month and Day

# %%
def get_most_recent_year_month_day():
    # path to lakehouse data available in notebook
    pqt_pth = Path("/lakehouse/default/Files/raw")

    # retrieve the most current listed path in the 
    pth_lst = [pth for pth in pqt_pth.glob("dt=*")]
    pth_lst.sort()
    cur_pth = pth_lst[-1]

    # pull out the date parts
    year, month, day = [int(val) for val in cur_pth.stem.lstrip('dt=').split('-')]

    return year,  month, day

# if year, month and day not provied as notbook paramaters, read from storage
if year == 0:
    year, month, day = get_most_recent_year_month_day()
# Out:
# StatementMeta(, ea3b6b13-c2f8-4484-aeb1-7bda22e32c2d, 7, Finished, Available, Finished)

# %% [markdown]
# ### Create Paths Based on Year, Month and Day

# %%
# create the datetimes string
dt_str = f'{year}-{month:02d}-{day:02d}'

# create the paths based on the delivery date
source_path = f'Files/raw/dt={year:04d}-{month:02d}-{day:02d}/places/parquet'
overlay_pth = f'Files/interim/places/overlay/parquet/delivery_year={year:04d}/delivery_month={month:02d}'
nooverlay_pth = f'Files/interim/places/nooverlay/parquet/delivery_year={year:04d}/delivery_month={month:02d}'
# Out:
# StatementMeta(, ea3b6b13-c2f8-4484-aeb1-7bda22e32c2d, 8, Finished, Available, Finished)

# %% [markdown]
# ### Ensure Spark Session Active

# %%
spark = SparkSession.builder.getOrCreate()

spark
# Out:
# StatementMeta(, ea3b6b13-c2f8-4484-aeb1-7bda22e32c2d, 9, Finished, Available, Finished)
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="https://sparkui.fabric.microsoft.com/sparkui/aee6e3c9-711e-4c7c-bd27-04f2307db20d/workspaceTypes/datacloud/workspaces/0d7f7c5d-07d9-46cf-8c65-a6b675718884/activities/ea3b6b13-c2f8-4484-aeb1-7bda22e32c2d/applications/application_1756938109434_0001/jobs?capacityId=aa1ba598-466a-4a13-bd85-6cdbbc1b14e6&pbiApi=api.fabric.microsoft.com&artifactId=2c2d29ff-52ef-4d9e-a15a-5827b4ad6d9d">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1.5.4.20250519.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>0.20-intersect-h3-geoanalytics_ea3b6b13-c2f8-4484-aeb1-7bda22e32c2d</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Read and Set Up Foursquare Data

# %%
# create the source path based on the delivery date
source_path = f'Files/raw/dt={dt_str}/places/parquet'

# read the data into a PySpark data frame
df = spark.read.parquet(source_path)

# add date columns
df = (df
    .withColumn('dt', fns.to_date(fns.lit(dt_str)))
    .withColumn('delivery_year', fns.lit(year))
    .withColumn('delivery_month', fns.lit(month))
)

# add geoanalytics point geometry
df = df.withColumn(
    'geometry', 
    fns_ga.point_from_binary(fns.col('geom'), sr=4326)
)

# add h3 indices
df = df.withColumn(h3_col, fns_ga.bin_id(fns_ga.h3_bin('geometry', h3_res)))

# keep foursquare id column consistent with past schema
df = df.withColumn(
    'fsq_id', fns.col('fsq_place_id')
)

# don't need the bounding box
df = df.drop(*['bbox', 'fsq_place_id', 'geom'])

# filter to just washington state
df = df.filter(
    (fns.col('country') == 'US')
    & (fns.col('region') == 'WA')
)

print(f'POI Count: {df.count():,}')
df.printSchema()
df.show(2, vertical=True, truncate=False)
# Out:
# StatementMeta(, ea3b6b13-c2f8-4484-aeb1-7bda22e32c2d, 10, Finished, Available, Finished)
# POI Count: 499,878
# root
#  |-- name: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- address: string (nullable = true)
#  |-- locality: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- postcode: string (nullable = true)
#  |-- admin_region: string (nullable = true)
#  |-- post_town: string (nullable = true)
#  |-- po_box: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- date_created: string (nullable = true)
#  |-- date_refreshed: string (nullable = true)
#  |-- date_closed: string (nullable = true)
#  |-- tel: string (nullable = true)
#  |-- website: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- facebook_id: long (nullable = true)
#  |-- instagram: string (nullable = true)
#  |-- twitter: string (nullable = true)
#  |-- fsq_category_ids: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fsq_category_labels: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- placemaker_url: string (nullable = true)
#  |-- unresolved_flags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- dt: date (nullable = true)
#  |-- delivery_year: integer (nullable = false)
#  |-- delivery_month: integer (nullable = false)
#  |-- geometry: point (nullable = true)
#  |-- h3_09: long (nullable = true)
#  |-- fsq_id: string (nullable = true)
#
# -RECORD 0---------------------------------------------------------------------------------------
#  name                | Rapid Garage Door Repair
#  latitude            | 32.60860126267354
#  longitude           | -85.47717332839966
#  address             | 12041 SE 313th Pl
#  locality            | Auburn
#  region              | WA
#  postcode            | 98092
#  admin_region        | NULL
#  post_town           | NULL
#  po_box              | NULL
#  country             | US
#  date_created        | 2025-02-07
#  date_refreshed      | 2025-02-07
#  date_closed         | NULL
#  tel                 | (253) 201-5970
#  website             | NULL
#  email               | NULL
#  facebook_id         | NULL
#  instagram           | NULL
#  twitter             | NULL
#  fsq_category_ids    | [63be6904847c3692a84b9b2b]
#  fsq_category_labels | [Business and Professional Services > Automotive Service]
#  placemaker_url      | https://foursquare.com/placemakers/review-place/67a60580ad8d590aedb024ad
#  unresolved_flags    | NULL
#  dt                  | 2025-08-07
#  delivery_year       | 2025
#  delivery_month      | 8
#  geometry            | {"x":-85.47717332839966,"y":32.60860126267354}
#  h3_09               | 618205804518965247
#  fsq_id              | 67a60580ad8d590aedb024ad
# -RECORD 1---------------------------------------------------------------------------------------
#  name                | Metropolitan Builders Inc
#  latitude            | 32.618285727601496
#  longitude           | -85.48075675964355
#  address             | NULL
#  locality            | Auburn
#  region              | WA
#  postcode            | 98023
#  admin_region        | NULL
#  post_town           | NULL
#  po_box              | NULL
#  country             | US
#  date_created        | 2015-01-28
#  date_refreshed      | 2015-01-28
#  date_closed         | NULL
#  tel                 | (360) 433-8386
#  website             | NULL
#  email               | NULL
#  facebook_id         | NULL
#  instagram           | NULL
#  twitter             | NULL
#  fsq_category_ids    | [4f2a210c4b9023bd5841ed28]
#  fsq_category_labels | [Community and Government > Housing Development]
#  placemaker_url      | https://foursquare.com/placemakers/review-place/54c8b7ff498eca919630b968
#  unresolved_flags    | NULL
#  dt                  | 2025-08-07
#  delivery_year       | 2025
#  delivery_month      | 8
#  geometry            | {"x":-85.48075675964355,"y":32.618285727601496}
#  h3_09               | 618205804563529727
#  fsq_id              | 54c8b7ff498eca919630b968
# only showing top 2 rows

# %% [markdown]
# ## Get Washington State From Living Atlas

# %%
df_poly = (
    spark.read.format("feature-service").load(poly_url)
    .select(
        fns.col("STATE_ABBR").alias("iso2"),
        fns.col("shape").alias("geometry")
    )
    .filter(fns.col("iso2") == "WA")
)

df_poly.printSchema()
df_poly.show()
# Out:
# StatementMeta(, ea3b6b13-c2f8-4484-aeb1-7bda22e32c2d, 11, Finished, Available, Finished)
# root
#  |-- iso2: string (nullable = true)
#  |-- geometry: polygon (nullable = true)
# +----+--------------------+
# |iso2|            geometry|
# +----+--------------------+
# |  WA|{"rings":[[[-122....|
# +----+--------------------+

# %% [markdown]
# ## Get H3 Indices Completely Within Polygon Geometry

# %%
@fns.udf(returnType=ArrayType(LongType()))
def poly_to_h3_within(geo_interface_geom: str) -> list[int]:
    """Get the H3 indices for an input polygon completely contained inside the polygon."""

    # if not a dictionary, convert to dictionary
    if not isinstance(geo_interface_geom, dict):
        geo_interface_geom = json.loads(geo_interface_geom)

    # convert the __geo_interface__ geometry (GeoJSON) to the h3 geometry
    h3_geom = h3_int.geo_to_h3shape(geo_interface_geom)

    # get the h3 indices completely within the polygon
    h3_idx_lst: list[int] = h3_int.h3shape_to_cells_experimental(h3_geom, res=h3_res, contain="full")

    return h3_idx_lst


df_poly_h3 = df_poly.select(
    fns.explode(
        poly_to_h3_within(
            fns_ga.as_geojson('geometry')
        )
    ).alias(h3_col),
    fns.col('iso2').alias('region_h3')
)

print(f"H3 Count: {df_poly_h3.count():,}")
df_poly_h3.printSchema()
df_poly_h3.show()
# Out:
# StatementMeta(, ea3b6b13-c2f8-4484-aeb1-7bda22e32c2d, 12, Submitted, Running, Running)
# H3 Count: 1,827,520
# root
#  |-- h3_09: long (nullable = true)
#  |-- region_h3: string (nullable = true)
#
# +------------------+---------+
# |             h3_09|region_h3|
# +------------------+---------+
# |617713351682949119|       WA|
# |617713351690551295|       WA|
# |617713351690813439|       WA|
# |617713351691075583|       WA|
# |617713351693434879|       WA|
# |617713351693697023|       WA|
# |617713351694745599|       WA|
# |617713352208809983|       WA|
# |617713332095287295|       WA|
# |617713332098695167|       WA|
# |617713332098957311|       WA|
# |617713332099219455|       WA|
# |617713332099481599|       WA|
# |617713352304754687|       WA|
# |617713352305016831|       WA|
# |617713352305278975|       WA|
# |617713352305541119|       WA|
# |617713352306065407|       WA|
# |617713332996276223|       WA|
# |617713332997849087|       WA|
# +------------------+---------+
# only showing top 20 rows

# %% [markdown]
# ## Identify Points Inside H3 Indices Wholly Within Washington

# %%
df_join = df.join(fns.broadcast(df_poly_h3), on=h3_col, how='left').cache()

df_join.printSchema()
# Out:
# StatementMeta(, , -1, Waiting, , Waiting)
# root
#  |-- h3_09: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- address: string (nullable = true)
#  |-- locality: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- postcode: string (nullable = true)
#  |-- admin_region: string (nullable = true)
#  |-- post_town: string (nullable = true)
#  |-- po_box: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- date_created: string (nullable = true)
#  |-- date_refreshed: string (nullable = true)
#  |-- date_closed: string (nullable = true)
#  |-- tel: string (nullable = true)
#  |-- website: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- facebook_id: long (nullable = true)
#  |-- instagram: string (nullable = true)
#  |-- twitter: string (nullable = true)
#  |-- fsq_category_ids: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fsq_category_labels: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- placemaker_url: string (nullable = true)
#  |-- unresolved_flags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- dt: date (nullable = true)
#  |-- delivery_year: integer (nullable = false)
#  |-- delivery_month: integer (nullable = false)
#  |-- geometry: point (nullable = true)
#  |-- fsq_id: string (nullable = true)
#  |-- region_h3: string (nullable = true)

# %%
df_outer = df_join.filter(fns.col("region_h3").isNull())
df_inner = df_join.filter(fns.col("region_h3").isNotNull())

print(f"Outer Count: {df_outer.count():,}")
print(f"Inner Count: {df_inner.count():,}")
# Out:
# StatementMeta(, , -1, Waiting, , Waiting)
# Outer Count: 25,932
# Inner Count: 473,946

# %% [markdown]
# ## Use Geometry Intersect with Outer Points

# %%
df_ovr = df_poly.select(
    fns.col('iso2').alias('region_ovr'),
    fns.col('geometry').alias('poly_geom')
)

df_ovr.printSchema()
# Out:
# StatementMeta(, , -1, Waiting, , Waiting)
# root
#  |-- region_ovr: string (nullable = true)
#  |-- poly_geom: polygon (nullable = true)

# %%
df_sptl_jn = (
    df_outer.join(
        other=df_ovr,
        on=fns_ga.intersects(
            geometry1=df_outer["geometry"], 
            geometry2=df_ovr["poly_geom"]
        ),
        how="left",
    )
    .drop('poly_geom')
).cache()

df_sptl_jn.printSchema()
df_sptl_jn.show(5, vertical=True, truncate=False)
# Out:
# StatementMeta(, , -1, Waiting, , Waiting)
# root
#  |-- h3_09: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- address: string (nullable = true)
#  |-- locality: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- postcode: string (nullable = true)
#  |-- admin_region: string (nullable = true)
#  |-- post_town: string (nullable = true)
#  |-- po_box: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- date_created: string (nullable = true)
#  |-- date_refreshed: string (nullable = true)
#  |-- date_closed: string (nullable = true)
#  |-- tel: string (nullable = true)
#  |-- website: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- facebook_id: long (nullable = true)
#  |-- instagram: string (nullable = true)
#  |-- twitter: string (nullable = true)
#  |-- fsq_category_ids: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fsq_category_labels: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- placemaker_url: string (nullable = true)
#  |-- unresolved_flags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- dt: date (nullable = true)
#  |-- delivery_year: integer (nullable = false)
#  |-- delivery_month: integer (nullable = false)
#  |-- geometry: point (nullable = true)
#  |-- fsq_id: string (nullable = true)
#  |-- region_h3: string (nullable = true)
#  |-- region_ovr: string (nullable = true)
#
# -RECORD 0---------------------------------------------------------------------------------------
#  h3_09               | 618205668034478079
#  name                | Waterwalls Inc.
#  latitude            | 32.35756072241322
#  longitude           | -86.30001068115234
#  address             | NULL
#  locality            | Enumclaw
#  region              | WA
#  postcode            | 98022
#  admin_region        | NULL
#  post_town           | NULL
#  po_box              | NULL
#  country             | US
#  date_created        | 2014-11-06
#  date_refreshed      | 2014-11-06
#  date_closed         | NULL
#  tel                 | (206) 271-7482
#  website             | NULL
#  email               | NULL
#  facebook_id         | NULL
#  instagram           | NULL
#  twitter             | NULL
#  fsq_category_ids    | [4bf58dd8d48988d1ff941735]
#  fsq_category_labels | [Retail > Miscellaneous Store]
#  placemaker_url      | https://foursquare.com/placemakers/review-place/545b3002498e08322d053384
#  unresolved_flags    | NULL
#  dt                  | 2025-08-07
#  delivery_year       | 2025
#  delivery_month      | 8
#  geometry            | {"x":-86.30001068115234,"y":32.35756072241322}
#  fsq_id              | 545b3002498e08322d053384
#  region_h3           | NULL
#  region_ovr          | NULL
# -RECORD 1---------------------------------------------------------------------------------------
#  h3_09               | 618205804518965247
#  name                | Rapid Garage Door Repair
#  latitude            | 32.60860126267354
#  longitude           | -85.47717332839966
#  address             | 12041 SE 313th Pl
#  locality            | Auburn
#  region              | WA
#  postcode            | 98092
#  admin_region        | NULL
#  post_town           | NULL
#  po_box              | NULL
#  country             | US
#  date_created        | 2025-02-07
#  date_refreshed      | 2025-02-07
#  date_closed         | NULL
#  tel                 | (253) 201-5970
#  website             | NULL
#  email               | NULL
#  facebook_id         | NULL
#  instagram           | NULL
#  twitter             | NULL
#  fsq_category_ids    | [63be6904847c3692a84b9b2b]
#  fsq_category_labels | [Business and Professional Services > Automotive Service]
#  placemaker_url      | https://foursquare.com/placemakers/review-place/67a60580ad8d590aedb024ad
#  unresolved_flags    | NULL
#  dt                  | 2025-08-07
#  delivery_year       | 2025
#  delivery_month      | 8
#  geometry            | {"x":-85.47717332839966,"y":32.60860126267354}
#  fsq_id              | 67a60580ad8d590aedb024ad
#  region_h3           | NULL
#  region_ovr          | NULL
# -RECORD 2---------------------------------------------------------------------------------------
#  h3_09               | 617759108942528511
#  name                | Nordstrom Rack
#  latitude            | 43.068207
#  longitude           | -76.171871
#  address             | 9090 Destiny Usa Dr
#  locality            | Syracuse
#  region              | WA
#  postcode            | 98101
#  admin_region        | NULL
#  post_town           | NULL
#  po_box              | NULL
#  country             | US
#  date_created        | 2022-01-01
#  date_refreshed      | 2025-04-20
#  date_closed         | 2025-04-20
#  tel                 | (888) 282-6060
#  website             | http://shop.nordstrom.com
#  email               | NULL
#  facebook_id         | NULL
#  instagram           | NULL
#  twitter             | NULL
#  fsq_category_ids    | NULL
#  fsq_category_labels | NULL
#  placemaker_url      | https://foursquare.com/placemakers/review-place/35bd1aaf1ce548262422f4f9
#  unresolved_flags    | NULL
#  dt                  | 2025-08-07
#  delivery_year       | 2025
#  delivery_month      | 8
#  geometry            | {"x":-76.171871,"y":43.068207}
#  fsq_id              | 35bd1aaf1ce548262422f4f9
#  region_h3           | NULL
#  region_ovr          | NULL
# -RECORD 3---------------------------------------------------------------------------------------
#  h3_09               | 617743121545428991
#  name                | Arborpro Lawn & Tree Care
#  latitude            | 40.963081106167465
#  longitude           | -76.6148892045021
#  address             | NULL
#  locality            | A Street
#  region              | WA
#  postcode            | 99004
#  admin_region        | NULL
#  post_town           | NULL
#  po_box              | NULL
#  country             | US
#  date_created        | 2015-05-18
#  date_refreshed      | 2017-04-04
#  date_closed         | NULL
#  tel                 | (509) 235-1132
#  website             | http://www.arborprolawn.com
#  email               | NULL
#  facebook_id         | NULL
#  instagram           | NULL
#  twitter             | NULL
#  fsq_category_ids    | [52e81612bcbc57f1066b7a24]
#  fsq_category_labels | [Landmarks and Outdoors > Tree]
#  placemaker_url      | https://foursquare.com/placemakers/review-place/55599cf3498ee652729baeeb
#  unresolved_flags    | NULL
#  dt                  | 2025-08-07
#  delivery_year       | 2025
#  delivery_month      | 8
#  geometry            | {"x":-76.6148892045021,"y":40.963081106167465}
#  fsq_id              | 55599cf3498ee652729baeeb
#  region_h3           | NULL
#  region_ovr          | NULL
# -RECORD 4---------------------------------------------------------------------------------------
#  h3_09               | 617675407509159935
#  name                | Bennett Solutions
#  latitude            | 32.97368904612499
#  longitude           | -96.7076037416333
#  address             | 1910 Firman Dr
#  locality            | Richardson
#  region              | WA
#  postcode            | 75081
#  admin_region        | NULL
#  post_town           | NULL
#  po_box              | NULL
#  country             | US
#  date_created        | 2018-08-09
#  date_refreshed      | 2020-04-23
#  date_closed         | NULL
#  tel                 | (425) 831-7924
#  website             | https://www.pcbennett.com
#  email               | NULL
#  facebook_id         | NULL
#  instagram           | NULL
#  twitter             | NULL
#  fsq_category_ids    | [52f2ab2ebcbc57f1066b8b36]
#  fsq_category_labels | [Business and Professional Services > Technology Business > IT Service]
#  placemaker_url      | https://foursquare.com/placemakers/review-place/5b6c08eeb54618002cb21110
#  unresolved_flags    | NULL
#  dt                  | 2025-08-07
#  delivery_year       | 2025
#  delivery_month      | 8
#  geometry            | {"x":-96.7076037416333,"y":32.97368904612499}
#  fsq_id              | 5b6c08eeb54618002cb21110
#  region_h3           | NULL
#  region_ovr          | NULL
# only showing top 5 rows

# %%
df_sptl_jn_not = df_sptl_jn.filter(fns.col('region_ovr').isNotNull())
df_sptl_jn_null = df_sptl_jn.filter(fns.col('region_ovr').isNull())

print(f"Overlay in WA Count: {df_sptl_jn_not.count():,}")
print(f"Overlay not in WA Count: {df_sptl_jn_null.count():,}")
# Out:
# StatementMeta(, , -1, Waiting, , Waiting)
# Overlay in WA Count: 23,666
# Overlay not in WA Count: 2,266
